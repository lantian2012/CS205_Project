# %%
import numpy as np
import h5py
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
f = h5py.File('/Users/tianlan/repo/CS205_Project/Data/hdf5/data_default.hdf5')
imarray = np.array(f['X_test'])[400, ]
imarray = np.reshape(imarray, (254, 384))
plt.imshow(imarray, cmap=plt.cm.gray)

# %%
f['X_test']
# Out:
# <HDF5 dataset "X_test": shape (490, 97536), type "<f4">
